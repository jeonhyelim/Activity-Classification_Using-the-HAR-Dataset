# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.17.1

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, Bidirectional, LSTM, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.decomposition import PCA
import scipy.stats
from google.colab import drive
import zipfile

# Google Drive mount
drive.mount('/content/drive')

# Define paths
zip_file_path = '/content/drive/MyDrive/Pattern_recognition_Assignment2/pr_project_train_data.zip'
extract_folder = '/content/drive/MyDrive/Pattern_recognition_Assignment2/pr_project_train_data'
model_save_folder = '/content/drive/MyDrive/Pattern_recognition_Assignment2/models3'

# Extract the test dataset zip file
if not os.path.exists(extract_folder):
    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        zip_ref.extractall(extract_folder)

# 중첩 디렉토리 처리
data_dir = extract_folder
while len(os.listdir(data_dir)) == 1 and os.path.isdir(os.path.join(data_dir, os.listdir(data_dir)[0])):
    data_dir = os.path.join(data_dir, os.listdir(data_dir)[0])

# Load dataset
def load_data(data_dir):
    X, y = [], []
    for file in os.listdir(data_dir):
        if file.endswith(".txt"):
            file_path = os.path.join(data_dir, file)
            data = np.loadtxt(file_path)
            X.append(data)
            y.append(int(file.split('_')[-1][0]))  # Extract class label from filename
    return np.array(X), np.array(y)

# extract features
def extract_features(X):
    features = []
    for sample in X:
        mean = np.mean(sample, axis=0)
        std = np.std(sample, axis=0)
        minimum = np.min(sample, axis=0)
        maximum = np.max(sample, axis=0)
        median = np.median(sample, axis=0)
        abs_mean = np.mean(np.abs(sample), axis=0)
        skewness = scipy.stats.skew(sample, axis=0)
        kurtosis = scipy.stats.kurtosis(sample, axis=0)
        sma = np.sum(np.abs(sample), axis=0)

        time_features = np.hstack([
            mean, std, minimum, maximum, median, abs_mean, skewness, kurtosis, sma
        ])

        fft = np.fft.rfft(sample, axis=0)
        fft_magnitude = np.abs(fft)
        fft_mean = np.mean(fft_magnitude, axis=0)
        fft_std = np.std(fft_magnitude, axis=0)
        fft_top_n = np.sort(fft_magnitude, axis=0)[-5:].flatten()
        freq_centroid = np.sum(np.arange(fft_magnitude.shape[0])[:, None] * fft_magnitude, axis=0) / np.sum(fft_magnitude, axis=0)
        freq_entropy = -np.sum((fft_magnitude / np.sum(fft_magnitude, axis=0)) * np.log(fft_magnitude / np.sum(fft_magnitude, axis=0) + 1e-10), axis=0)
        power_spectrum = np.sum(fft_magnitude ** 2, axis=0)

        freq_features = np.hstack([
            fft_mean, fft_std, fft_top_n, freq_centroid, freq_entropy, power_spectrum
        ])

        features.append(np.hstack([time_features, freq_features]))
    return np.array(features)

# Load and preprocess data
X_raw, y_raw = load_data(data_dir)
X_features = extract_features(X_raw)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_features)

encoder = OneHotEncoder(sparse_output=False)
y_encoded = encoder.fit_transform(y_raw.reshape(-1, 1))

# PCA for dimensionality reduction
pca = PCA(n_components=min(150, min(X_scaled.shape[0], X_scaled.shape[1])))
X_pca = pca.fit_transform(X_scaled)

X_train, X_val, y_train, y_val = train_test_split(X_pca, y_encoded, test_size=0.2, random_state=42)

# CNN model
def build_cnn_model(input_shape, num_classes):
    model = Sequential([
        Conv1D(64, kernel_size=3, activation='relu', input_shape=(input_shape, 1)),
        MaxPooling1D(pool_size=2),
        Conv1D(128, kernel_size=3, activation='relu'),
        MaxPooling1D(pool_size=2),
        Flatten(),
        Dense(256, activation='relu'),
        Dropout(0.4),
        Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# BiLSTM model
def build_bilstm_model(input_shape, num_classes):
    model = Sequential([
        Bidirectional(LSTM(256, return_sequences=True)),
        Dropout(0.4),
        BatchNormalization(),
        Bidirectional(LSTM(128)),
        Dense(256, activation='relu'),
        Dropout(0.4),
        Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Train and evaluate function
def train_and_evaluate(model, model_name):
    callbacks = [
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)
        ]
    if model_name == "cnn_model":
        X_train_reshaped = np.expand_dims(X_train, axis=-1)
        X_val_reshaped = np.expand_dims(X_val, axis=-1)
        model.fit(X_train_reshaped, y_train, validation_data=(X_val_reshaped, y_val), epochs=50, batch_size=32, callbacks=callbacks)
        model_path = os.path.join(model_save_folder, "cnn_model.keras")
    elif model_name == "bilstm_model":
        X_train_reshaped = np.expand_dims(X_train, axis=-1)
        X_val_reshaped = np.expand_dims(X_val, axis=-1)
        model.fit(X_train_reshaped, y_train, validation_data=(X_val_reshaped, y_val), epochs=50, batch_size=32, callbacks=callbacks)
        model_path = os.path.join(model_save_folder, "bilstm_model.keras")
    model.save(model_path)
    _, accuracy = model.evaluate(X_val_reshaped, y_val, verbose=0)
    return accuracy, model_path

# Train models
cnn_model = build_cnn_model(X_pca.shape[1], y_encoded.shape[1])
cnn_acc, cnn_model_path = train_and_evaluate(cnn_model, "cnn_model")

bilstm_model = build_bilstm_model((X_pca.shape[1], 1), y_encoded.shape[1])
bilstm_acc, bilstm_model_path = train_and_evaluate(bilstm_model, "bilstm_model")

# Ensemble results
print('\n-------|  Ensemble Results  |-------')
ensemble_acc = (cnn_acc + bilstm_acc) / 2
print(f'Ensemble Accuracy: {ensemble_acc:.2%}')

# Compare results and print
if cnn_acc > bilstm_acc:
    final_model_path = cnn_model_path
    print('\n-------|  Final Result  |----------')
    print('CNN Accuracy     : {:.2%}'.format(cnn_acc))
    print('BiLSTM Accuracy  : {:.2%}'.format(bilstm_acc))
    print("\nCNN model is superior. Selected as the final model.")
    print('Final Accuracy   : {:.2%}'.format(cnn_acc))
    print(f"\nCNN model saved at {final_model_path}.")
else:
    final_model_path = bilstm_model_path
    print('\n-------|  Final Result  |----------')
    print('CNN Accuracy     : {:.2%}'.format(cnn_acc))
    print('BiLSTM Accuracy  : {:.2%}'.format(bilstm_acc))
    print("\nBiLSTM model is superior. Selected as the final model.")
    print('Final Accuracy   : {:.2%}'.format(bilstm_acc))
    print(f"\nBiLSTM model saved at {final_model_path}.")
# Out:
# Mounted at /content/drive
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.5229 - loss: 1.1043 - val_accuracy: 0.7912 - val_loss: 0.5527 - learning_rate: 0.0010
# Epoch 2/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7791 - loss: 0.5439 - val_accuracy: 0.8085 - val_loss: 0.4444 - learning_rate: 0.0010
# Epoch 3/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8273 - loss: 0.4282 - val_accuracy: 0.8451 - val_loss: 0.3923 - learning_rate: 0.0010
# Epoch 4/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8430 - loss: 0.3753 - val_accuracy: 0.8379 - val_loss: 0.3850 - learning_rate: 0.0010
# Epoch 5/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8560 - loss: 0.3463 - val_accuracy: 0.8501 - val_loss: 0.3652 - learning_rate: 0.0010
# Epoch 6/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8715 - loss: 0.3161 - val_accuracy: 0.8451 - val_loss: 0.3908 - learning_rate: 0.0010
# Epoch 7/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8814 - loss: 0.2918 - val_accuracy: 0.8601 - val_loss: 0.3487 - learning_rate: 0.0010
# Epoch 8/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8886 - loss: 0.2744 - val_accuracy: 0.8594 - val_loss: 0.3554 - learning_rate: 0.0010
# Epoch 9/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9067 - loss: 0.2429 - val_accuracy: 0.8472 - val_loss: 0.3712 - learning_rate: 0.0010
# Epoch 10/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9158 - loss: 0.2120 - val_accuracy: 0.8651 - val_loss: 0.3735 - learning_rate: 0.0010
# Epoch 11/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9047 - loss: 0.2329 - val_accuracy: 0.8659 - val_loss: 0.3550 - learning_rate: 0.0010
# Epoch 12/50
# 163/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9226 - loss: 0.1925
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9226 - loss: 0.1928 - val_accuracy: 0.8659 - val_loss: 0.3716 - learning_rate: 0.0010
# Epoch 13/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9321 - loss: 0.1641 - val_accuracy: 0.8766 - val_loss: 0.3633 - learning_rate: 5.0000e-04
# Epoch 14/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9417 - loss: 0.1509 - val_accuracy: 0.8680 - val_loss: 0.3692 - learning_rate: 5.0000e-04
# Epoch 15/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9538 - loss: 0.1245 - val_accuracy: 0.8709 - val_loss: 0.3869 - learning_rate: 5.0000e-04
# Epoch 16/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9504 - loss: 0.1187 - val_accuracy: 0.8737 - val_loss: 0.3873 - learning_rate: 5.0000e-04
# Epoch 17/50
# 162/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9588 - loss: 0.1114
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9586 - loss: 0.1118 - val_accuracy: 0.8759 - val_loss: 0.3840 - learning_rate: 5.0000e-04
# Epoch 18/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9695 - loss: 0.0909 - val_accuracy: 0.8723 - val_loss: 0.3824 - learning_rate: 2.5000e-04
# Epoch 19/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9679 - loss: 0.0855 - val_accuracy: 0.8809 - val_loss: 0.3968 - learning_rate: 2.5000e-04
# Epoch 20/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9769 - loss: 0.0782 - val_accuracy: 0.8788 - val_loss: 0.3988 - learning_rate: 2.5000e-04
# Epoch 21/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9770 - loss: 0.0731 - val_accuracy: 0.8737 - val_loss: 0.4071 - learning_rate: 2.5000e-04
# Epoch 22/50
# 167/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9757 - loss: 0.0691
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9757 - loss: 0.0690 - val_accuracy: 0.8802 - val_loss: 0.4069 - learning_rate: 2.5000e-04
# Epoch 23/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9791 - loss: 0.0670 - val_accuracy: 0.8745 - val_loss: 0.4252 - learning_rate: 1.2500e-04
# Epoch 24/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9773 - loss: 0.0658 - val_accuracy: 0.8816 - val_loss: 0.4152 - learning_rate: 1.2500e-04
# Epoch 25/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9852 - loss: 0.0539 - val_accuracy: 0.8752 - val_loss: 0.4261 - learning_rate: 1.2500e-04
# Epoch 26/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9855 - loss: 0.0560 - val_accuracy: 0.8730 - val_loss: 0.4375 - learning_rate: 1.2500e-04
# Epoch 27/50
# 159/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9885 - loss: 0.0502
# Epoch 27: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9883 - loss: 0.0503 - val_accuracy: 0.8780 - val_loss: 0.4376 - learning_rate: 1.2500e-04
# Epoch 28/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9870 - loss: 0.0495 - val_accuracy: 0.8745 - val_loss: 0.4326 - learning_rate: 6.2500e-05
# Epoch 29/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0479 - val_accuracy: 0.8716 - val_loss: 0.4378 - learning_rate: 6.2500e-05
# Epoch 30/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9867 - loss: 0.0469 - val_accuracy: 0.8745 - val_loss: 0.4383 - learning_rate: 6.2500e-05
# Epoch 31/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9886 - loss: 0.0430 - val_accuracy: 0.8788 - val_loss: 0.4377 - learning_rate: 6.2500e-05
# Epoch 32/50
# 166/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9895 - loss: 0.0439
# Epoch 32: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9893 - loss: 0.0440 - val_accuracy: 0.8788 - val_loss: 0.4376 - learning_rate: 6.2500e-05
# Epoch 33/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9901 - loss: 0.0431 - val_accuracy: 0.8816 - val_loss: 0.4393 - learning_rate: 3.1250e-05
# Epoch 34/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9916 - loss: 0.0386 - val_accuracy: 0.8780 - val_loss: 0.4457 - learning_rate: 3.1250e-05
# Epoch 35/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9887 - loss: 0.0433 - val_accuracy: 0.8788 - val_loss: 0.4441 - learning_rate: 3.1250e-05
# Epoch 36/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9891 - loss: 0.0415 - val_accuracy: 0.8795 - val_loss: 0.4432 - learning_rate: 3.1250e-05
# Epoch 37/50
# 164/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9892 - loss: 0.0438
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9892 - loss: 0.0436 - val_accuracy: 0.8816 - val_loss: 0.4381 - learning_rate: 3.1250e-05
# Epoch 38/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9909 - loss: 0.0396 - val_accuracy: 0.8788 - val_loss: 0.4413 - learning_rate: 1.5625e-05
# Epoch 39/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9894 - loss: 0.0405 - val_accuracy: 0.8788 - val_loss: 0.4459 - learning_rate: 1.5625e-05
# Epoch 40/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9905 - loss: 0.0390 - val_accuracy: 0.8773 - val_loss: 0.4467 - learning_rate: 1.5625e-05
# Epoch 41/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9931 - loss: 0.0365 - val_accuracy: 0.8773 - val_loss: 0.4486 - learning_rate: 1.5625e-05
# Epoch 42/50
# 155/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9924 - loss: 0.0374
# Epoch 42: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9923 - loss: 0.0373 - val_accuracy: 0.8795 - val_loss: 0.4482 - learning_rate: 1.5625e-05
# Epoch 43/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9943 - loss: 0.0352 - val_accuracy: 0.8773 - val_loss: 0.4497 - learning_rate: 7.8125e-06
# Epoch 44/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.
# Epoch 26/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8484 - loss: 0.3827
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.8484 - loss: 0.3827 - val_accuracy: 0.7862 - val_loss: 0.5478 - learning_rate: 0.0010
# Epoch 27/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8589 - loss: 0.3481 - val_accuracy: 0.8207 - val_loss: 0.4781 - learning_rate: 5.0000e-04
# Epoch 28/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.8748 - loss: 0.3045 - val_accuracy: 0.8264 - val_loss: 0.4773 - learning_rate: 5.0000e-04
# Epoch 29/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.8787 - loss: 0.2871 - val_accuracy: 0.8228 - val_loss: 0.4815 - learning_rate: 5.0000e-04
# Epoch 30/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.8803 - loss: 0.2851 - val_accuracy: 0.8235 - val_loss: 0.4863 - learning_rate: 5.0000e-04
# Epoch 31/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8844 - loss: 0.2896
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.8844 - loss: 0.2896 - val_accuracy: 0.8286 - val_loss: 0.4807 - learning_rate: 5.0000e-04
# Epoch 32/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8977 - loss: 0.2514 - val_accuracy: 0.8235 - val_loss: 0.4845 - learning_rate: 2.5000e-04
# Epoch 33/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.9051 - loss: 0.2312 - val_accuracy: 0.8257 - val_loss: 0.4723 - learning_rate: 2.5000e-04
# Epoch 34/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.9149 - loss: 0.2189 - val_accuracy: 0.8221 - val_loss: 0.4865 - learning_rate: 2.5000e-04
# Epoch 35/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.9087 - loss: 0.2267 - val_accuracy: 0.8250 - val_loss: 0.5088 - learning_rate: 2.5000e-04
# Epoch 36/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9159 - loss: 0.2105
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.9158 - loss: 0.2106 - val_accuracy: 0.8228 - val_loss: 0.5106 - learning_rate: 2.5000e-04
# Epoch 37/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.9176 - loss: 0.2069 - val_accuracy: 0.8300 - val_loss: 0.5112 - learning_rate: 1.2500e-04
# Epoch 38/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.9132 - loss: 0.2037 - val_accuracy: 0.8185 - val_loss: 0.5291 - learning_rate: 1.2500e-04
# Epoch 39/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.9237 - loss: 0.1919 - val_accuracy: 0.8257 - val_loss: 0.5249 - learning_rate: 1.2500e-04
# Epoch 40/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.9189 - loss: 0.1949 - val_accuracy: 0.8286 - val_loss: 0.5292 - learning_rate: 1.2500e-04
# Epoch 41/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9270 - loss: 0.1880
# Epoch 41: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.9270 - loss: 0.1880 - val_accuracy: 0.8221 - val_loss: 0.5447 - learning_rate: 1.2500e-04
# Epoch 42/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.9318 - loss: 0.1662 - val_accuracy: 0.8235 - val_loss: 0.5390 - learning_rate: 6.2500e-05
# Epoch 43/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.9281 - loss: 0.1805 - val_accuracy: 0.8242 - val_loss: 0.5453 - learning_rate: 6.2500e-05
# Epoch 44/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.9363 - loss: 0.1712 - val_accuracy: 0.8242 - val_loss: 0.5546 - learning_rate: 6.2500e-05
# Epoch 45/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9239 - loss: 0.1795 - val_accuracy: 0.8221 - val_loss: 0.5520 - learning_rate: 6.2500e-05
# Epoch 46/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9298 - loss: 0.1721
# Epoch 46: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.9298 - loss: 0.1721 - val_accuracy: 0.8207 - val_loss: 0.5606 - learning_rate: 6.2500e-05
# Epoch 47/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9330 - loss: 0.1708 - val_accuracy: 0.8250 - val_loss: 0.5616 - learning_rate: 3.1250e-05
# Epoch 48/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.9349 - loss: 0.1608 - val_accuracy: 0.8207 - val_loss: 0.5619 - learning_rate: 3.1250e-05
# Epoch 49/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.9318 - loss: 0.1684 - val_accuracy: 0.8235 - val_loss: 0.5617 - learning_rate: 3.1250e-05
# Epoch 50/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.9330 - loss: 0.1683 - val_accuracy: 0.8293 - val_loss: 0.5605 - learning_rate: 3.1250e-05
#
# -------|  Ensemble Results  |-------
# Ensemble Accuracy: 85.40%
#
# -------|  Final Result  |----------
# CNN Accuracy     : 87.88%
# BiLSTM Accuracy  : 82.93%
#
# CNN model is superior. Selected as the final model.
# Final Accuracy   : 87.88%
#
# CNN model saved at /content/drive/MyDrive/Pattern_recognition_Assignment2/models3/cnn_model.keras.
